# %%
import requests
import ollama

# %%
PROMPT = """
"""
CONTENTS = """
Hello, could you introduce yourself?
"""

# %%
url = "http://localhost:11434/api/chat"
data = {
    "model": "phi3:latest",
    "messages": [
        {"role": "user", "content": f"Prompt: {PROMPT} Question: {CONTENTS}"}
    ],
    "stream": False
}
response = requests.post(url, json=data)
result = response.json()

print(result["message"]["content"])
# Out:
# <|bot|>Greetings! I'm PhiBot, a cutting-static AI developed by NexusAI. My purpose is to assist users with their inquiries and provide them with the most accurate information available up until my last update on January 31st, 2024. How can I help you today?

# %%
client = ollama.Client(host="http://localhost:11434")

response = client.chat(
    model="phi3:latest",
    messages=[{"role": "user", "content": f"Prompt: {PROMPT} Question: {CONTENTS}"}],
)

print(response["message"]["content"])
# Out:
# Certainly! I'm an AI developed to assist with tasks and provide information. My name is not fixed; it changes according to my role or the context in which they are needed - for now, let's call me "Assistant." How can I help you today?

# %%
with open("./train_text_classification_bert.py", "r", encoding="utf-8") as f:
    code_str = f.read()

# %%
PROMPT = 'Please briefly summarize the following code.\n'
CONTENTS = code_str

# %%
client = ollama.Client(host="http://localhost:11434")

response = client.chat(
    model="phi3:latest",
    messages=[{"role": "user", "content": f"Prompt: {PROMPT} Question: {CONTENTS}"}],
)

print(response["message"]["content"])
# Out:
# The code imports necessary libraries and sets environment variables for CUDA device selection. It loads IMDB dataset preprocessed as pickle files, creates PyTorch Tensor datasets from these arrays, splits them into train/validation/test subsets with a DataLoader function (with the option to use multiple workers).
#
# The main sequence of code begins by defining and initializing constants like batch size, number of epochs, patience for early stopping etc. It also defines learning rates parameters in `lr` dictionary which will be used in optimizer & scheduler setup later on.  The model is instantiated as a pretrained BERT-based sequence classifier (AutoModelForSequenceClassification).
#
# If GPU_PARALLEL flag is true, it wraps the created model with torch.nn.DataParallel for multi-GPU parallel processing to speed up training time and enable larger batches of data input per device if available in system memory - this helps achieve better performance on systems equipped with multiple CUDA devices as BERT models are computationally intensive tasks during their forward pass operations which benefit from GPU acceleration.
#
# The code uses CrossEntropyLoss for the loss function & AdamW optimizer is chosen to fine-tune model parameters through backpropagation, while CosineAnnealingWarmRestarts scheduler controls learning rate decay over time based on a specific schedule (with period T_0 and multiplier).
#
# Finally it calls main script Train for the training process of BERT with different attention types ('neg' & 'pos'). This customized Training class would be responsible to run through epochs, monitor validation loss, apply early stopping when no improvement is seen in specific number of times (patience), save best model etc. and also manage logging by redirecting stdout into a log file during this process which provides visibility on the training status & progress for post-evaluation or debugging purposes if needed later downstream tasks like analysis/visualization, anomaly detection, hyperparameter tuning using learning curves etc., thereby completing an encapsulating machine learning workflow pipeline.
