# %%
import requests

# %%
PROMPT = """
"""
CONTENTS = """
Hello, could you introduce yourself?
"""

# %%
url = "http://localhost:11434/api/chat"
data = {
    "model": "phi3:latest",
    "messages": [
        {"role": "user", "content": f"Prompt: {PROMPT} Question: {CONTENTS}"}
    ],
    "stream": False
}
response = requests.post(url, json=data)
result = response.json()

print(result["message"]["content"])
# Out:
# Greetings! I am an AI developed to assist and provide information. My capabilities include answering questions across a wide range of topics such as science, history, technology, language translation, and more. How may I help you today?
